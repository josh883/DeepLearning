# %%
import platform

print(f"I am running on Google's servers: {platform.node()}")
# Out:
# I am running on Google's servers: DESKTOP-BJR7GP7

# %% [markdown]
# #local test Success

# %%
name = input("Enter your name: ")
print(f"Happy coding, {name}!")
# Out:
# Happy coding, josh!
